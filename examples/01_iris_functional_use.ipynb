# %%
import sys
sys.path.append('../')

# %%
import prepnet

import pandas as pd
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn import datasets

# %%
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target_names[iris.target]
display(df.head())
df.hist(figsize=(8, 12))
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B8D8454348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8D8485BC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B8D86B3308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8D86E7D08>]],
#       dtype=object)

# %% [markdown]
# # Preprocess using prepnet

# %%
df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                object
# dtype: object

# %%
preprocess = {}
for col in df.columns:
    if df.dtypes[col].kind == 'f':
        proc = prepnet.Standardize()
    else:
        proc = prepnet.OrdinalConverter()
    df.loc[:, col] = proc.encode(df[col])
    preprocess[col] = proc
display(df.head())
df.hist(figsize=(8, 12))
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0          -0.897674          1.015602          -1.335752         -1.311052
# 1          -1.139200         -0.131539          -1.335752         -1.311052
# 2          -1.380727          0.327318          -1.392399         -1.311052
# 3          -1.501490          0.097889          -1.279104         -1.311052
# 4          -1.018437          1.245030          -1.335752         -1.311052
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B8D7ED5388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8D7EDB5C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B8D7E45B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8D7FF9408>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B8D81E3F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8D6FCAD08>]],
#       dtype=object)

# %%
model = SVC()
classifier = OneVsRestClassifier(model)
classifier.fit(df.drop(columns=['target']), df['target'])
classifier.predict
# Out:
# OneVsRestClassifier(estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                                   class_weight=None, coef0=0.0,
#                                   decision_function_shape='ovr', degree=3,
#                                   gamma='scale', kernel='rbf', max_iter=-1,
#                                   probability=False, random_state=None,
#                                   shrinking=True, tol=0.001, verbose=False),
#                     n_jobs=None)
